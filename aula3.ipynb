# %% [markdown]
# <a href="https://colab.research.google.com/github/batman1405/1F-grupo-B/blob/main/aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lado1 = 2
lado2 = 3

#Cálculo da area

area = lado1 * lado2

#cálculo de um quadrado

areaquadrado = lado1 * lado1

# %%
print(area)
# Out:
# 6

# %%
name="Marina"
idade= 14
altura= 1.75

# %%
print(name)
# Out:
# Marina

# %%
name="Batman"

# %%
name="Nina"

# %%
print(f"name: {name}, altura: {altura}, idade: {idade}")
# Out:
# name: Marina, altura: 1.75, idade: 14
