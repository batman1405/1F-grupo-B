# %% [markdown]
# <a href="https://colab.research.google.com/github/batman1405/1F-grupo-B/blob/main/expert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Entrada
lado1 = float(input("Digite o comprimento:"))
lado2 = float(input("Digite a altura:"))

#Processamento

area = lado1 * lado2

#Saída

print(f"o total da área é : {area} metros quadrados")
# Out:
# Digite o comprimento:3
# Digite a altura:9
# o total da área é : 27.0 metros quadrados

# %%
#Entrada

numero = float(input("digite o numero:"))

#Processamento

subtracao = numero - 2

#Saída

print(f"a subtracao do numero é:{subtracao}")
# Out:
# digite o numero:5
# a subtracao do numero é:3.0

# %%
#Entrada

numero1 = float(input("digite um numero"))
numero2 = float(input("digite um numero"))
numero3= float(input("digite um numero"))
numero4= float(input("digite um numero"))

#Processamento

média = float(numero1 + numero2 + numero3+ numero4)/4

#Saída

print(f"a média do numero é:{média}")
# Out:
# digite um numero7
# digite um numero8
# digite um numero7
# digite um numero8
# a média do numero é:7.5

# %%
#Entrada

nome = str(input("digite o nome"))
idade = int(input("digite a idade"))

#Saída

print (f"Olá {nome}")
print (f"sua idade é: {numero}")
# Out:
# digite o nomenina
# digite a idade67
# Olá nina
# sua idade é: 8.0

# %%
#Entrada

numero = float(input("digite um numero:"))

#Processamento

dobro = numero * 2

#Saída

print(f"o dobro do numero é: {dobro}")
# Out:
# digite um numero:5
# o dobro do numero é: 10.0
